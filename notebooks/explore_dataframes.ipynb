# %% [markdown]
# # DataFrame Exploration
#
# This notebook defines helper functions to load the pre-built dataframes from
# `src.data.load_excel_sheets` and then displays several of them to verify that
# they look as expected.

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\notebooks

# %%
# Import Required Modules
import importlib
from typing import Dict
import sys
import pathlib

import pandas as pd

# Ensure workspace root is on path so 'src' and 'config' can be imported
root = pathlib.Path.cwd().parents[0]
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

# Import the loader module
from src.data import load_excel_sheets

# Reload to get the latest version if the module was edited during the session
load_excel_sheets = importlib.reload(load_excel_sheets)

print("✓ Loader module imported successfully from", load_excel_sheets.__file__)
# Out:
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDNOK Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDKRW Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDSGD Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDTWD Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDMXN Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDCNH Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDINR Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'BBDXY Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'EMFXDBET Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'USGG2YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'USGG5YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'USGG10YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'S0042FS 3M1M BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'S0042FS 6M1M BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'S0042FS 1Y1M BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'RR2YHUS Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'SPX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'FTW5000 Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'INDU Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'MXUS Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'BCOM Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'CO1 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'XAU Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'FN1 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'TZT1 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'NG1 COMB Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'HGA Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'LMCADS03 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'VIX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'MOVE Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'JPMVG71M Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GECU2YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GECU5YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GECU10YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'RR2YHEA Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GTITL10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GTDEM10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'SXXP Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'GTJPY2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'GTJPY5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'GTJPY10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'G0018 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'G0018 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'G0018 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'JYSST10 BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'NXY Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'GTCHF2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'GTCHF5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'GTCHF10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'G0082 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'G0082 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'G0082 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'SMI Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'GTGBP2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'GTGBP5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'GTGBP10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'RR2YHGB Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'UKX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'MCX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'GTNZD2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'GTNZD5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'G0049 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'G0049 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'G0049 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'RR2YHnz Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'NZX20X Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'OMRA Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'FSPA Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'GTAUD2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'GTAUD5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'G0001 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'G0001 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'G0001 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'RR2YHAU Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'AS51 Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'SCOH6 COMB Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'IACA COMB Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'GTCAD2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'G0007 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'G0007 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'G0007 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'RR2YHCA Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'SPTSX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'USCRWCAS Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'GTNOK2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'GTNOK5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'GTNOK10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'G0078 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'G0078 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'G0078 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'RR2YHNO Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'GTSEK2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'GTSEK5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'GTSEK10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'G0021 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'G0021 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'G0021 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'OMX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDNOK Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDKRW Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDSGD Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDTWD Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDMXN Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDCNH Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDINR Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'BBDXY Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'EMFXDBET Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'USGG2YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'USGG5YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'USGG10YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'S0042FS 3M1M BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'S0042FS 6M1M BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'S0042FS 1Y1M BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'RR2YHUS Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'SPX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'FTW5000 Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'INDU Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'MXUS Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'BCOM Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'CO1 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'XAU Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'FN1 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'TZT1 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'NG1 COMB Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'HGA Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'LMCADS03 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'VIX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'MOVE Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'JPMVG71M Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GECU2YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GECU5YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GECU10YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'RR2YHEA Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GTITL10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GTDEM10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'SXXP Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'GTJPY2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'GTJPY5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'GTJPY10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'G0018 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'G0018 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'G0018 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'JYSST10 BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'NXY Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'GTCHF2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'GTCHF5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'GTCHF10YR Corp'; those rows will be NaT
#   warnings.warn(
# ✓ Loader module imported successfully from c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'G0082 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'G0082 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'G0082 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'SMI Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'GTGBP2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'GTGBP5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'GTGBP10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'RR2YHGB Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'UKX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'MCX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'GTNZD2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'GTNZD5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'G0049 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'G0049 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'G0049 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'RR2YHnz Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'NZX20X Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'OMRA Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'FSPA Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'GTAUD2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'GTAUD5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'G0001 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'G0001 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'G0001 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'RR2YHAU Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'AS51 Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'SCOH6 COMB Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'IACA COMB Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'GTCAD2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'G0007 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'G0007 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'G0007 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'RR2YHCA Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'SPTSX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'USCRWCAS Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'GTNOK2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'GTNOK5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'GTNOK10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'G0078 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'G0078 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'G0078 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'RR2YHNO Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'GTSEK2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'GTSEK5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'GTSEK10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'G0021 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'G0021 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'G0021 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'OMX Index'; those rows will be NaT
#   warnings.warn(

# %%
# Define Helper Functions to Load DataFrames

def get_sheet_dataframes(module) -> Dict[str, pd.DataFrame]:
    """Return a dictionary of attribute name to DataFrame found in `module`.

    The loader module exposes variables like ``fx_df`` etc.  We extract those
    by filtering for names that end with "_df" and are DataFrame objects.
    """
    result: Dict[str, pd.DataFrame] = {}
    for name in dir(module):
        if name.endswith("_df"):
            attr = getattr(module, name)
            if isinstance(attr, pd.DataFrame):
                result[name] = attr
    return result


def load_all() -> Dict[str, pd.DataFrame]:
    """Reload the loader module and return all dataframes.
    
    The loader automatically resolves paths from config.py, so no path argument
    is needed here. This function simply triggers a reload and extracts the
    module-level dataframe variables.
    """
    mod = importlib.reload(load_excel_sheets)
    return get_sheet_dataframes(mod)

# %%
# Load DataFrames from Python File

frames = load_all()
frames
# Out:
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDNOK Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDKRW Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDSGD Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDTWD Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDMXN Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDCNH Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'USDINR Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'BBDXY Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'FX', column 'EMFXDBET Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'USGG2YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'USGG5YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'USGG10YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'S0042FS 3M1M BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'S0042FS 6M1M BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'S0042FS 1Y1M BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'RR2YHUS Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'SPX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'FTW5000 Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'INDU Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'MXUS Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'BCOM Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'CO1 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'XAU Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'FN1 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'TZT1 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'NG1 COMB Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'HGA Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'LMCADS03 Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'VIX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'MOVE Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'USD', column 'JPMVG71M Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GECU2YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GECU5YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GECU10YR Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'RR2YHEA Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GTITL10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'GTDEM10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'EUR', column 'SXXP Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'GTJPY2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'GTJPY5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'GTJPY10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'G0018 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'G0018 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'G0018 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'JYSST10 BLC Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'JPY', column 'NXY Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'GTCHF2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'GTCHF5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'GTCHF10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'G0082 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'G0082 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'G0082 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CHF', column 'SMI Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'GTGBP2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'GTGBP5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'GTGBP10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'RR2YHGB Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'UKX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'GBP', column 'MCX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'GTNZD2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'GTNZD5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'G0049 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'G0049 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'G0049 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'RR2YHnz Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'NZX20X Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'OMRA Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NZD', column 'FSPA Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'GTAUD2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'GTAUD5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'G0001 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'G0001 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'G0001 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'RR2YHAU Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'AS51 Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'SCOH6 COMB Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'AUD', column 'IACA COMB Comdty'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'GTCAD2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'G0007 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'G0007 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'G0007 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'RR2YHCA Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'SPTSX Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'CAD', column 'USCRWCAS Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'GTNOK2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'GTNOK5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'GTNOK10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'G0078 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'G0078 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'G0078 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'NOK', column 'RR2YHNO Index'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'GTSEK2YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'GTSEK5YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'GTSEK10YR Corp'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'G0021 3M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'G0021 6M1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'G0021 1Y1M BLC2 Curncy'; those rows will be NaT
#   warnings.warn(
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\data\load_excel_sheets.py:85: UserWarning: Unable to parse some dates in sheet 'SEK', column 'OMX Index'; those rows will be NaT
#   warnings.warn(
# {'aud_df':             GTAUD2YR Corp  GTAUD5YR Corp  GTAUD10YR Corp  \
#  2000-03-01          6.108          6.515           6.550
#  2000-03-02          6.155          6.590           6.665
#  2000-03-03          6.115          6.575           6.605
#  2000-03-06          6.420          6.760           6.755
#  2000-03-07          6.430          6.785           6.685
#  ...                   ...            ...             ...
#  2026-02-13          4.241          4.388           4.748
#  2026-02-16          4.222          4.362           4.709
#  2026-02-17          4.186          4.331           4.685
#  2026-02-18          4.219          4.368           4.723
#  NaT                   NaN            NaN             NaN
#
#              G0001 3M1M BLC2 Curncy  G0001 6M1M BLC2 Curncy  \
#  2000-03-01                     NaN                     NaN
#  2000-03-02                     NaN                     NaN
#  2000-03-03                     NaN                     NaN
#  2000-03-06                     NaN                     NaN
#  2000-03-07                     NaN                     NaN
#  ...                            ...                     ...
#  2026-02-13                 4.11403                 4.22824
#  2026-02-16                 4.13371                 4.20408
#  2026-02-17                 4.10455                 4.17293
#  2026-02-18                 4.13220                 4.20384
#  NaT                            NaN                     NaN
#
#              G0001 1Y1M BLC2 Curncy  RR2YHAU Index  AS51 Index  \
#  2000-03-01                     NaN           3.31    3187.200
#  2000-03-02                     NaN           3.36    3219.800
#  2000-03-03                     NaN           3.32    3232.600
#  2000-03-06                     NaN           3.62    3214.000
#  2000-03-07                     NaN           3.63    3232.500
#  2000-03-01            2.815         NaN           1773.0      21.64
#  2000-03-02            2.783         NaN           1752.0      21.06
#  2000-03-03            2.825         NaN           1761.0      19.21
#  2000-03-06            2.850         NaN           1768.0      21.50
#  2000-03-07            2.799         NaN           1749.0      24.31
#  ...                     ...         ...              ...        ...
#  2026-02-13            3.243      586.25          12881.0      20.60
#  2026-02-16              NaN         NaN          12850.5      21.20
#  2026-02-17            3.031      570.40          12619.5      20.29
#  2026-02-18            2.974      584.80              NaN      18.98
#  NaT                     NaN         NaN              NaN        NaN
#
#              MOVE Index  JPMVG71M Index
#  2000-03-01      104.14             NaN
#  2000-03-02       99.68             NaN
#  2000-03-03       94.85             NaN
#  2000-03-06       92.06             NaN
#  2000-03-07       97.13             NaN
#  ...                ...             ...
#  2026-02-13       70.10            7.73
#  2026-02-16         NaN            7.31
#  2026-02-17       68.84            7.30
#  2026-02-18         NaN            7.30
#  NaT                NaN             NaN
#
#  [6777 rows x 25 columns]}

# %%
# Verify Loaded DataFrames

for name, df in frames.items():
    print(f"{name}: {df.shape}")
    display(df.head())
# Out:
# aud_df: (6776, 10)
#             GTAUD2YR Corp  GTAUD5YR Corp  GTAUD10YR Corp  \
# 2000-03-01          6.108          6.515           6.550
# 2000-03-02          6.155          6.590           6.665
# 2000-03-03          6.115          6.575           6.605
# 2000-03-06          6.420          6.760           6.755
# 2000-03-07          6.430          6.785           6.685
#
#             G0001 3M1M BLC2 Curncy  G0001 6M1M BLC2 Curncy  \
# 2000-03-01                     NaN                     NaN
# 2000-03-02                     NaN                     NaN
# 2000-03-03                     NaN                     NaN
# 2000-03-06                     NaN                     NaN
# 2000-03-07                     NaN                     NaN
#
#             G0001 1Y1M BLC2 Curncy  RR2YHAU Index  AS51 Index  \
# 2000-03-01                     NaN           3.31      3187.2
# 2000-03-02                     NaN           3.36      3219.8
# 2000-03-03                     NaN           3.32      3232.6
# 2000-03-06                     NaN           3.62      3214.0
# 2000-03-07                     NaN           3.63      3232.5
#
#             SCOH6 COMB Comdty  IACA COMB Comdty
# 2000-03-01                NaN               NaN
# 2000-03-02                NaN               NaN
# 2000-03-03                NaN               NaN
# 2000-03-06                NaN               NaN
# 2000-03-07                NaN               NaN
# cad_df: (6777, 9)
#             GTCAD2YR Corp  GTCAD5YR Corp  GTCAD10YR Corp  \
# 2000-03-01          5.976          6.171           6.098
# 2000-03-02          5.997          6.185           6.110
# 2000-03-03          5.953          6.143           6.086
# 2000-03-06          6.004          6.205           6.135
# 2000-03-07          5.959          6.173           6.116
#
#             G0007 3M1M BLC2 Curncy  G0007 6M1M BLC2 Curncy  \
# 2000-03-01                 5.87310                 5.90442
# 2000-03-02                 5.89260                 5.92402
# 2000-03-03                 5.85179                 5.88394
# 2000-03-06                 5.89864                 5.93105
# 2000-03-07                 5.85504                 5.88863
#
#             G0007 1Y1M BLC2 Curncy  RR2YHCA Index  SPTSX Index  USCRWCAS Index
# 2000-03-01                 5.87263           2.93      9411.58             NaN
# 2000-03-01          6.504          6.571           6.386
# 2000-03-02          6.513          6.583           6.384
# 2000-03-03          6.495          6.593           6.388
# 2000-03-06          6.529          6.625           6.411
# 2000-03-07          6.486          6.569           6.373
#
#             S0042FS 3M1M BLC Curncy  S0042FS 6M1M BLC Curncy  \
# 2000-03-01                      NaN                      NaN
# 2000-03-02                      NaN                      NaN
# 2000-03-03                      NaN                      NaN
# 2000-03-06                      NaN                      NaN
# 2000-03-07                      NaN                      NaN
#
#             S0042FS 1Y1M BLC Curncy  RR2YHUS Index  SPX Index  FTW5000 Index  \
# 2000-03-01                      NaN        2.74186    1379.19     13950.2895
# 2000-03-02                      NaN        2.75086    1381.76     13940.8971
# 2000-03-03                      NaN        2.73286    1409.17     14262.9495
# 2000-03-06                      NaN        2.76686    1391.28     14141.8140
# 2000-03-07                      NaN        2.72386    1355.62     13837.3736
#
#             INDU Index  ...  CO1 Comdty  XAU Curncy  FN1 Comdty  TZT1 Comdty  \
# 2000-03-01    10137.93  ...       29.06      289.75       11.99          NaN
# 2000-03-02    10164.92  ...       29.22      288.50       11.72          NaN
# 2000-03-03    10367.20  ...       28.99      288.80       11.65          NaN
# 2000-03-06    10170.51  ...       29.63      287.63       11.67          NaN
# 2000-03-07     9796.04  ...       31.90      293.25       11.69          NaN
#
#             NG1 COMB Comdty  HGA Comdty  LMCADS03 Comdty  VIX Index  \
# 2000-03-01            2.815         NaN           1773.0      21.64
# 2000-03-02            2.783         NaN           1752.0      21.06
# 2000-03-03            2.825         NaN           1761.0      19.21
# 2000-03-06            2.850         NaN           1768.0      21.50
# 2000-03-07            2.799         NaN           1749.0      24.31
#
#             MOVE Index  JPMVG71M Index
# 2000-03-01      104.14             NaN
# 2000-03-02       99.68             NaN
# 2000-03-03       94.85             NaN
# 2000-03-06       92.06             NaN
# 2000-03-07       97.13             NaN
#
# [5 rows x 25 columns]

# %%
  # Template: Drop Columns from DataFrames

def drop_columns(df: pd.DataFrame, columns_to_drop: list[str]) -> pd.DataFrame:
    """Drop specified columns from a dataframe.
    
    Parameters
    ----------
    df : pd.DataFrame
        The dataframe to filter.
    columns_to_drop : list[str]
        List of column names to remove.
    
    Returns
    -------
    pd.DataFrame
         dataframe with specified columns removed.
        
    Raises
    ------
    ValueError
        If any specified column doesn't exist in the dataframe.
    """
    missing = [col for col in columns_to_drop if col not in df.columns]
    if missing:
        raise ValueError(f"Columns not found in dataframe: {missing}")
    
    return df.drop(columns=columns_to_drop)


# Example: Drop columns from sek_df
sek_df = drop_columns(
    frames["sek_df"],
    columns_to_drop=[
        "G0021 3M1M BLC2 Curncy",
        "G0021 6M1M BLC2 Curncy",
        "G0021 1Y1M BLC2 Curncy"
    ]
)

print(f"\nRemaining columns in sek_df:\n{list(sek_df.columns)}")
print(f"Original sek_df shape: {frames['sek_df'].shape}")
print(f" sek_df shape: {sek_df.shape}")



# Example: Drop columns from nok_df
nok_df = drop_columns(
    frames["nok_df"],
    columns_to_drop=[
        "G0078 3M1M BLC2 Curncy",
        "G0078 6M1M BLC2 Curncy",
        "G0078 1Y1M BLC2 Curncy"
    ]
)

print(f"\nRemaining columns in nok_df:\n{list(nok_df.columns)}")
print(f"Original nok_df shape: {frames['nok_df'].shape}")
print(f" nok_df shape: {nok_df.shape}")

# Example: Drop columns from aud_df
aud_df = drop_columns(
    frames["aud_df"],
    columns_to_drop=[
        "G0001 3M1M BLC2 Curncy",
        "G0001 6M1M BLC2 Curncy",
        "G0001 1Y1M BLC2 Curncy"
    ]
)

print(f"\nRemaining columns in aud_df:\n{list(aud_df.columns)}")
print(f"Original aud_df shape: {frames['aud_df'].shape}")
print(f" aud_df shape: {aud_df.shape}")


# Example: Drop columns from nzd_df
nzd_df = drop_columns(
    frames["nzd_df"],
    columns_to_drop=[
        "G0049 3M1M BLC2 Curncy",
        "G0049 6M1M BLC2 Curncy",
        "G0049 1Y1M BLC2 Curncy",
    ]
)

print(f"\nRemaining columns in nzd_df:\n{list(nzd_df.columns)}")
print(f"Original nzd_df shape: {frames['nzd_df'].shape}")
print(f" nzd_df shape: {nzd_df.shape}")


# Example: Drop columns from chf_df
chf_df = drop_columns(
    frames["chf_df"],
    columns_to_drop=[
        "G0082 3M1M BLC2 Curncy",
        "G0082 6M1M BLC2 Curncy",
        "G0082 1Y1M BLC2 Curncy"
    ]
)

print(f"\nRemaining columns in chf_df:\n{list(chf_df.columns)}")
print(f"Original chf_df shape: {frames['chf_df'].shape}")
print(f" chf_df shape: {chf_df.shape}")


# Example: Drop columns from jpy_df
jpy_df = drop_columns(
    frames["jpy_df"],
    columns_to_drop=[
        "G0018 3M1M BLC2 Curncy",
        "G0018 6M1M BLC2 Curncy",
        "G0018 1Y1M BLC2 Curncy"
    ]
)

print(f"\nRemaining columns in jpy_df:\n{list(jpy_df.columns)}")
print(f"Original jpy_df shape: {frames['jpy_df'].shape}")
print(f" jpy_df shape: {jpy_df.shape}")


fx_df = frames["fx_df"]
print(f"\nColumns in fx_df:\n{list(fx_df.columns)}")
print(f" jpy_df shape: {fx_df.shape}")

usd_df = frames["usd_df"]
print(f"\nColumns in usd_df:\n{list(usd_df.columns)}")
print(f" usd_df shape: {usd_df.shape}")

eur_df = frames["eur_df"]
print(f"\nColumns in eur_df:\n{list(eur_df.columns)}")
print(f" eur_df shape: {eur_df.shape}")

gbp_df = frames["gbp_df"]
print(f"\nColumns in gbp_df:\n{list(gbp_df.columns)}")
print(f" gbp_df shape: {gbp_df.shape}")

cad_df = frames["cad_df"]
print(f"\nColumns in cad_df:\n{list(cad_df.columns)}")
print(f" cad_df shape: {cad_df.shape}")
# Out:
# Remaining columns in sek_df:
# ['GTSEK2YR Corp', 'GTSEK5YR Corp', 'GTSEK10YR Corp', 'RR2YHSE Index', 'OMX Index']
# Original sek_df shape: (6754, 8)
#  sek_df shape: (6754, 5)
#
# Remaining columns in nok_df:
# ['GTNOK2YR Corp', 'GTNOK5YR Corp', 'GTNOK10YR Corp', 'RR2YHNO Index', 'OBX Index']
# Original nok_df shape: (6717, 8)
#  nok_df shape: (6717, 5)
#
# Remaining columns in aud_df:
# ['GTAUD2YR Corp', 'GTAUD5YR Corp', 'GTAUD10YR Corp', 'RR2YHAU Index', 'AS51 Index', 'SCOH6 COMB Comdty', 'IACA COMB Comdty']
# Original aud_df shape: (6776, 10)
#  aud_df shape: (6776, 7)
#
# Remaining columns in nzd_df:
# ['GTNZD2YR Corp', 'GTNZD5YR Corp', 'GTNZD10YR Corp', 'RR2YHnz Index', 'NZX20X Index', 'OMRA Comdty', 'FSPA Comdty']
# Original nzd_df shape: (6720, 10)
#  nzd_df shape: (6720, 7)
#
# Remaining columns in chf_df:
# ['GTCHF2YR Corp', 'GTCHF5YR Corp', 'GTCHF10YR Corp', 'RR2YHCH Index', 'SMI Index']
# Original chf_df shape: (6701, 8)
#  chf_df shape: (6701, 5)
#
# Remaining columns in jpy_df:
# ['GTJPY2YR Corp', 'GTJPY5YR Corp', 'GTJPY10YR Corp', 'RR2YHJP Index', 'JYSST10 BLC Curncy', 'NXY Index']
# Original jpy_df shape: (6773, 9)
#  jpy_df shape: (6773, 6)
#
# Columns in fx_df:
# ['EURUSD Curncy', 'GBPUSD Curncy', 'AUDUSD Curncy', 'NZDUSD Curncy', 'USDJPY Curncy', 'USDCHF Curncy', 'USDCAD Curncy', 'USDNOK Curncy', 'USDSEK Curncy', 'USDKRW Curncy', 'USDSGD Curncy', 'USDTWD Curncy', 'USDMXN Curncy', 'USDCNH Curncy', 'USDINR Curncy', 'BBDXY Curncy', 'EMFXDBET Index', 'CTTWBUSA Index']
#  jpy_df shape: (6777, 18)
#
# Columns in usd_df:
# ['USGG2YR Index', 'USGG5YR Index', 'USGG10YR Index', 'S0042FS 3M1M BLC Curncy', 'S0042FS 6M1M BLC Curncy', 'S0042FS 1Y1M BLC Curncy', 'RR2YHUS Index', 'SPX Index', 'FTW5000 Index', 'INDU Index', 'MXUS Index', 'MXWO Index', 'MXWOU Index', 'MXEF Index', 'BCOM Index', 'CO1 Comdty', 'XAU Curncy', 'FN1 Comdty', 'TZT1 Comdty', 'NG1 COMB Comdty', 'HGA Comdty', 'LMCADS03 Comdty', 'VIX Index', 'MOVE Index', 'JPMVG71M Index']
#  usd_df shape: (6777, 25)
#
# Columns in eur_df:
# ['GECU2YR Index', 'GECU5YR Index', 'GECU10YR Index', 'G0013 3M1M BLC2 Curncy', 'G0013 6M1M BLC2 Curncy', 'G0013 1Y1M BLC2 Curncy', 'RR2YHEA Index', 'GTITL10YR Corp', 'GTDEM10YR Corp', 'SXXP Index']
#  eur_df shape: (6777, 10)
#
# Columns in gbp_df:
# ['GTGBP2YR Corp', 'GTGBP5YR Corp', 'GTGBP10YR Corp', 'G0022 3M1M BLC2 Curncy', 'G0022 6M1M BLC2 Curncy', 'G0022 1Y1M BLC2 Curncy', 'RR2YHGB Index', 'UKX Index', 'MCX Index']
#  gbp_df shape: (6777, 9)
#
# Columns in cad_df:
# ['GTCAD2YR Corp', 'GTCAD5YR Corp', 'GTCAD10YR Corp', 'G0007 3M1M BLC2 Curncy', 'G0007 6M1M BLC2 Curncy', 'G0007 1Y1M BLC2 Curncy', 'RR2YHCA Index', 'SPTSX Index', 'USCRWCAS Index']
#  cad_df shape: (6777, 9)

# %%
fx_df = frames["fx_df"]
fx_df.tail()
# Out:
#             EURUSD Curncy  GBPUSD Curncy  AUDUSD Curncy  NZDUSD Curncy  \
# 2026-02-13         1.1868         1.3651         0.7073         0.6039
# 2026-02-16         1.1851         1.3629         0.7072         0.6033
# 2026-02-17         1.1855         1.3568         0.7086         0.6049
# 2026-02-18         1.1823         1.3547         0.7069         0.5991
# NaT                   NaN            NaN            NaN            NaN
#
#             USDJPY Curncy  USDCHF Curncy  USDCAD Curncy  USDNOK Curncy  \
# 2026-02-13         152.70         0.7685         1.3617         9.5102
# 2026-02-16         153.47            NaN         1.3636         9.5078
# 2026-02-17         153.31         0.7718         1.3636         9.5324
# 2026-02-18         154.34         0.7723         1.3666         9.4896
# NaT                   NaN            NaN            NaN            NaN
#
#             USDSEK Curncy  USDKRW Curncy  USDSGD Curncy  USDTWD Curncy  \
# 2026-02-13         8.9225        1444.10         1.2629         31.511
# 2026-02-16         8.9474        1444.43         1.2626         31.440
# 2026-02-17         8.9684        1445.15         1.2631         31.430
# 2026-02-18         8.9917        1450.10         1.2653         31.450
# NaT                   NaN            NaN            NaN            NaN
#
#             USDMXN Curncy  USDCNH Curncy  USDINR Curncy  BBDXY Curncy  \
# 2026-02-13        17.1701         6.9012        90.6400       1181.35
# 2026-02-16        17.1683         6.8844        90.6537       1182.95
# 2026-02-17        17.1283         6.8852        90.6850       1183.30
# 2026-02-18        17.1274         6.8867        90.6788       1185.77
# NaT                   NaN            NaN            NaN           NaN
#
#             EMFXDBET Index  CTTWBUSA Index
# 2026-02-13          213.34        103.3611
# 2026-02-16             NaN        103.1725
# 2026-02-17             NaN        103.2271
# 2026-02-18             NaN        103.2615
# NaT                    NaN             NaN

# %%
import numpy as np

# --- 1. Setup: constituent columns and weights ---
cols = [
    "EURUSD Curncy", "USDJPY Curncy", "USDCAD Curncy", "GBPUSD Curncy", "USDMXN Curncy",
    "USDCNH Curncy", "USDCHF Curncy", "AUDUSD Curncy", "USDKRW Curncy", "USDINR Curncy",
    "USDSGD Curncy", "USDTWD Curncy"
]
base_weights = np.array([0.2947, 0.1238, 0.1165, 0.1027, 0.0962, 0.0700, 0.0447, 0.0439, 0.0316, 0.0283, 0.0261, 0.0215])
w = pd.Series(base_weights, index=cols)

# --- 2. Reindex all constituent prices to BBDXY's valid index ---
bbdxy_index = fx_df["BBDXY Curncy"].dropna().index
px = fx_df[cols].reindex(bbdxy_index)

# --- 3. Oriented log returns matrix ---
signs = np.where([c.startswith("USD") for c in cols], 1, -1)
log_px = np.log(px)
R_df = (signs * log_px.diff())
R_df = R_df.fillna(0.0)  # fill missing returns with 0.0

# --- 4. Exclusion weight matrix ---
exclusions = ["EURUSD Curncy", "USDJPY Curncy", "USDCHF Curncy", "GBPUSD Curncy", "AUDUSD Curncy", "USDCAD Curncy"]
K = len(exclusions)
W_ex = np.tile(w.values, (K,1)).T  # shape (12,K)
for k, excl in enumerate(exclusions):
    W_ex[cols.index(excl), k] = 0  # set excluded weight to 0
W_ex = pd.DataFrame(W_ex, index=cols, columns=exclusions)

# --- 5. CNH regime split ---
CNH_START = pd.Timestamp("2010-08-23")
pre_mask = R_df.index < CNH_START
post_mask = R_df.index >= CNH_START

def normalize_weights(W, cnh_active):
    Wn = W.copy()
    if not cnh_active:
        Wn.loc["USDCNH Curncy", :] = 0  # remove CNH
    Wn = Wn.div(Wn.sum(axis=0), axis=1)
    return Wn

W_pre = normalize_weights(W_ex, cnh_active=False)
W_post = normalize_weights(W_ex, cnh_active=True)

# --- 6. Compute weighted returns (matrix multiplication) ---
R_pre = R_df.loc[pre_mask]
R_post = R_df.loc[post_mask]

r_pre_df = R_pre.dot(W_pre)
r_post_df = R_post.dot(W_post)

# --- 7. Concatenate, compute index levels ---
r_all = pd.concat([r_pre_df, r_post_df]).sort_index()
base_level = fx_df["BBDXY Curncy"].dropna().iloc[0]
idx_all = base_level * np.exp(r_all.cumsum())

# --- 8. Name columns as required ---
colnames = [
    "BBDXY_ex_EUR", "BBDXY_ex_JPY", "BBDXY_ex_CHF",
    "BBDXY_ex_GBP", "BBDXY_ex_AUD", "BBDXY_ex_CAD"
]
idx_all.columns = colnames

# --- 9. # Concatenate the new synthetic indices with the original fx_df
fx_newdf = pd.concat([fx_df, idx_all], axis=1)

# Optionally: correlation with official BBDXY
print("\nCorrelation with BBDXY Curncy:")
print(fx_newdf.corrwith(fx_df["BBDXY Curncy"]))
# Out:
# Correlation with BBDXY Curncy:
# EURUSD Curncy    -0.950283
# GBPUSD Curncy    -0.824525
# AUDUSD Curncy    -0.849447
# NZDUSD Curncy    -0.699782
# USDJPY Curncy     0.733054
# USDCHF Curncy    -0.332388
# USDCAD Curncy     0.944063
# USDNOK Curncy     0.947768
# USDSEK Curncy     0.946021
# USDKRW Curncy     0.638940
# USDSGD Curncy    -0.022591
# USDTWD Curncy     0.051277
# USDMXN Curncy     0.854253
# USDCNH Curncy     0.717168
# USDINR Curncy     0.871522
# BBDXY Curncy      1.000000
# EMFXDBET Index    0.088961
# CTTWBUSA Index    0.644069
# BBDXY_ex_EUR      0.974325
# BBDXY_ex_JPY      0.983610
# BBDXY_ex_CHF      0.989565
# BBDXY_ex_GBP      0.989097
# BBDXY_ex_AUD      0.992806
# BBDXY_ex_CAD      0.991335
# dtype: float64

# %%
fx_newdf.tail()
# Out:
#             EURUSD Curncy  GBPUSD Curncy  AUDUSD Curncy  NZDUSD Curncy  \
# 2026-02-13         1.1868         1.3651         0.7073         0.6039
# 2026-02-16         1.1851         1.3629         0.7072         0.6033
# 2026-02-17         1.1855         1.3568         0.7086         0.6049
# 2026-02-18         1.1823         1.3547         0.7069         0.5991
# NaT                   NaN            NaN            NaN            NaN
#
#             USDJPY Curncy  USDCHF Curncy  USDCAD Curncy  USDNOK Curncy  \
# 2026-02-13         152.70         0.7685         1.3617         9.5102
# 2026-02-16         153.47            NaN         1.3636         9.5078
# 2026-02-17         153.31         0.7718         1.3636         9.5324
# 2026-02-18         154.34         0.7723         1.3666         9.4896
# NaT                   NaN            NaN            NaN            NaN
#
#             USDSEK Curncy  USDKRW Curncy  ...  USDINR Curncy  BBDXY Curncy  \
# 2026-02-13         8.9225        1444.10  ...        90.6400       1181.35
# 2026-02-16         8.9474        1444.43  ...        90.6537       1182.95
# 2026-02-17         8.9684        1445.15  ...        90.6850       1183.30
# 2026-02-18         8.9917        1450.10  ...        90.6788       1185.77
# NaT                   NaN            NaN  ...            NaN           NaN
#
#             EMFXDBET Index  CTTWBUSA Index  BBDXY_ex_EUR  BBDXY_ex_JPY  \
# 2026-02-13          213.34        103.3611   1239.829679   1180.561599
# 2026-02-16             NaN        103.1725   1241.119038   1181.279735
# 2026-02-17             NaN        103.2271   1241.220200   1181.397261
# 2026-02-18             NaN        103.2615   1243.957780   1183.450460
# NaT                    NaN             NaN           NaN           NaN
#
#             BBDXY_ex_CHF  BBDXY_ex_GBP  BBDXY_ex_AUD  BBDXY_ex_CAD
# 2026-02-13   1255.696109   1189.751500   1218.299418   1225.299425
# 2026-02-16   1257.215920   1191.064739   1219.764813   1226.677488
# 2026-02-17   1257.160692   1190.397705   1219.822038   1226.619223
# 2026-02-18   1260.219429   1193.308389   1222.689609   1229.530453
# NaT                  NaN           NaN           NaN           NaN
#
# [5 rows x 24 columns]

# %%
# Mapping of currency DataFrames and their corresponding fx_newdf columns to add
currency_map = {
    'eur': {
        'df': eur_df,
        'fx_cols': ['EURUSD Curncy', 'BBDXY_ex_EUR', 'EMFXDBET Index']
    },
    'gbp': {
        'df': gbp_df,
        'fx_cols': ['GBPUSD Curncy', 'BBDXY_ex_GBP', 'EMFXDBET Index']
    },
    'jpy': {
        'df': jpy_df,
        'fx_cols': ['USDJPY Curncy', 'BBDXY_ex_JPY', 'CTTWBUSA Index']
    },
    'chf': {
        'df': chf_df,
        'fx_cols': ['USDCHF Curncy', 'BBDXY_ex_CHF', 'EMFXDBET Index']
    },
    'cad': {
        'df': cad_df,
        'fx_cols': ['USDCAD Curncy', 'BBDXY_ex_CAD', 'EMFXDBET Index']
    },
    'aud': {
        'df': aud_df,
        'fx_cols': ['AUDUSD Curncy', 'BBDXY_ex_AUD', 'CTTWBUSA Index']
    },
    'nzd': {
        'df': nzd_df,
        'fx_cols': ['NZDUSD Curncy', 'BBDXY Curncy', 'CTTWBUSA Index']
    },
    'nok': {
        'df': nok_df,
        'fx_cols': ['USDNOK Curncy', 'BBDXY Curncy', 'EMFXDBET Index']
    },
    'sek': {
        'df': sek_df,
        'fx_cols': ['USDSEK Curncy', 'BBDXY Curncy', 'EMFXDBET Index']
    }
}

# Validate all required fx_newdf columns exist
required_fx_cols = set(col for v in currency_map.values() for col in v['fx_cols'])
missing_cols = required_fx_cols - set(fx_newdf.columns)
if missing_cols:
    raise ValueError(f"Missing required columns in fx_newdf: {sorted(missing_cols)}")

# Create new DataFrames and store in a dictionary
df2_map = {}

for cur, info in currency_map.items():
    # Combine original currency DataFrame with usd_df (align by index)
    df2 = pd.concat([info['df'], usd_df], axis=1)
    # Add required fx_newdf columns (align by index)
    fx_cols_to_add = fx_newdf[info['fx_cols']]
    df2 = pd.concat([df2, fx_cols_to_add], axis=1)
    # Store in globals and in the dictionary
    globals()[f"{cur}_df2"] = df2
    df2_map[f"{cur}_df2"] = df2

# Sanity check: print shapes of all new DataFrames
for name, df in df2_map.items():
    print(f"{name}: {df.shape}")
# Out:
# eur_df2: (6777, 38)
# gbp_df2: (6777, 37)
# jpy_df2: (6777, 34)
# chf_df2: (6777, 33)
# cad_df2: (6777, 37)
# aud_df2: (6777, 35)
# nzd_df2: (6777, 35)
# nok_df2: (6777, 33)
# sek_df2: (6777, 33)
# C:\Users\tilik\AppData\Local\Temp\ipykernel_8948\266683616.py:52: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   df2 = pd.concat([info['df'], usd_df], axis=1)

# %%
nok_df2.tail()
# Out:
#             GTNOK2YR Corp  GTNOK5YR Corp  GTNOK10YR Corp  RR2YHNO Index  \
# 2026-02-13          4.078          4.119           4.255            NaN
# 2026-02-16          4.061          4.111           4.246            NaN
# 2026-02-17          3.992          4.061           4.192            NaN
# 2026-02-18          3.987          4.062           4.209            NaN
# NaT                   NaN            NaN             NaN            NaN
#
#             OBX Index  USGG2YR Index  USGG5YR Index  USGG10YR Index  \
# 2026-02-13    1752.55         3.4076         3.6038          4.0483
# 2026-02-16    1754.19         3.4076         3.6038          4.0483
# 2026-02-17    1747.13         3.4325         3.6210          4.0578
# 2026-02-18    1785.47         3.4637         3.6504          4.0769
# NaT               NaN            NaN            NaN             NaN
#
#             S0042FS 3M1M BLC Curncy  S0042FS 6M1M BLC Curncy  ...  \
# 2026-02-13                   3.5660                   3.3176  ...
# 2026-02-16                   3.5660                   3.3176  ...
# 2026-02-17                   3.5642                   3.3339  ...
# 2026-02-18                   3.5721                   3.3474  ...
# NaT                             NaN                      NaN  ...
#
#             TZT1 Comdty  NG1 COMB Comdty  HGA Comdty  LMCADS03 Comdty  \
# 2026-02-13       32.500            3.243      586.25          12881.0
# 2026-02-16       30.903              NaN         NaN          12850.5
# 2026-02-17       29.822            3.031      570.40          12619.5
# 2026-02-18       31.410            2.974      584.80              NaN
# NaT                 NaN              NaN         NaN              NaN
#
#             VIX Index  MOVE Index  JPMVG71M Index  USDNOK Curncy  \
# 2026-02-13      20.60       70.10            7.73         9.5102
# 2026-02-16      21.20         NaN            7.31         9.5078
# 2026-02-17      20.29       68.84            7.30         9.5324
# 2026-02-18      18.98         NaN            7.30         9.4896
# NaT               NaN         NaN             NaN            NaN
#
#             BBDXY Curncy  EMFXDBET Index
# 2026-02-13       1181.35          213.34
# 2026-02-16       1182.95             NaN
# 2026-02-17       1183.30             NaN
# 2026-02-18       1185.77             NaN
# NaT                  NaN             NaN
#
# [5 rows x 33 columns]

# %%
# Drop specified columns from selected DataFrames
cols_to_drop = [
    'S0042FS 3M1M BLC Curncy',
    'S0042FS 6M1M BLC Curncy',
    'S0042FS 1Y1M BLC Curncy'
]
for df_name in ['sek_df2', 'nok_df2', 'aud_df2', 'nzd_df2', 'chf_df2', 'jpy_df2']:
    df = globals().get(df_name)
    if df is not None:
        # Drop columns if they exist
        df.drop(columns=[col for col in cols_to_drop if col in df.columns], inplace=True)
        df2_map[df_name] = df
# Print shapes after dropping columns
for name in ['sek_df2', 'nok_df2', 'aud_df2', 'nzd_df2', 'chf_df2', 'jpy_df2']:
    print(f"{name}: {globals()[name].shape}")
# Out:
# sek_df2: (6777, 30)
# nok_df2: (6777, 30)
# aud_df2: (6777, 32)
# nzd_df2: (6777, 32)
# chf_df2: (6777, 30)
# jpy_df2: (6777, 31)

# %%
sek_df2.tail()
# Out:
#             GTSEK2YR Corp  GTSEK5YR Corp  GTSEK10YR Corp  RR2YHSE Index  \
# 2026-02-13          1.874          2.188           2.653            NaN
# 2026-02-16          1.870          2.185           2.652            NaN
# 2026-02-17          1.863          2.176           2.646            NaN
# 2026-02-18          1.859          2.177           2.650            NaN
# NaT                   NaN            NaN             NaN            NaN
#
#             OMX Index  USGG2YR Index  USGG5YR Index  USGG10YR Index  \
# 2026-02-13   3119.757         3.4076         3.6038          4.0483
# 2026-02-16   3121.803         3.4076         3.6038          4.0483
# 2026-02-17   3130.122         3.4325         3.6210          4.0578
# 2026-02-18   3168.084         3.4637         3.6504          4.0769
# NaT               NaN            NaN            NaN             NaN
#
#             RR2YHUS Index  SPX Index  ...  TZT1 Comdty  NG1 COMB Comdty  \
# 2026-02-13       0.939432    6836.17  ...       32.500            3.243
# 2026-02-16       0.939432        NaN  ...       30.903              NaN
# 2026-02-17       0.964332    6843.22  ...       29.822            3.031
# 2026-02-18       0.995532    6894.24  ...       31.410            2.974
# NaT                   NaN        NaN  ...          NaN              NaN
#
#             HGA Comdty  LMCADS03 Comdty  VIX Index  MOVE Index  \
# 2026-02-13      586.25          12881.0      20.60       70.10
# 2026-02-16         NaN          12850.5      21.20         NaN
# 2026-02-17      570.40          12619.5      20.29       68.84
# 2026-02-18      584.80              NaN      18.98         NaN
# NaT                NaN              NaN        NaN         NaN
#
#             JPMVG71M Index  USDSEK Curncy  BBDXY Curncy  EMFXDBET Index
# 2026-02-13            7.73         8.9225       1181.35          213.34
# 2026-02-16            7.31         8.9474       1182.95             NaN
# 2026-02-17            7.30         8.9684       1183.30             NaN
# 2026-02-18            7.30         8.9917       1185.77             NaN
# NaT                    NaN            NaN           NaN             NaN
#
# [5 rows x 30 columns]

# %%
# --- 1. Helper functions ---

def log_return(series):
    """Compute log returns, preserving index."""
    return np.log(series / series.shift(1))

def daily_change(series):
    """Compute daily value change, preserving index."""
    return series.diff()

def transform_series(series, col_name):
    """
    Apply the correct transformation to a series based on its name.
    - daily_change if name endswith BLC Curncy, BLC2 Curncy, YR Index, YR Corp, or startswith RR2YH
    - log_return otherwise
    """
    if (
        col_name.endswith("BLC Curncy")
        or col_name.endswith("BLC2 Curncy")
        or col_name.endswith("YR Index")
        or col_name.endswith("YR Corp")
        or col_name.startswith("RR2YH")
    ):
        return daily_change(series)
    else:
        return log_return(series)

def build_driver(df, spec):
    """
    Build a driver series from a DataFrame and a driver spec.
    - If type == 'single', transform the specified column.
    - If type == 'spread', transform left and right, then subtract.
    Returns None if required columns are missing.
    """
    if spec["type"] == "single":
        col = spec["col"]
        if col in df.columns:
            return transform_series(df[col], col)
        else:
            return None
    elif spec["type"] == "spread":
        left, right = spec["left"], spec["right"]
        if left in df.columns and right in df.columns:
            return transform_series(df[left], left) - transform_series(df[right], right)
        else:
            return None
    else:
        raise ValueError(f"Unknown driver spec type: {spec['type']}")

def process_dataframe(df, driver_specs):
    """
    Process a DataFrame according to driver_specs.
    - Forward-fill missing values.
    - For each driver, build the series if possible.
    - Rename commodity columns if commodity_rename is provided.
    - Drop the first row (NaN from diff/log).
    - Return processed DataFrame with only driver columns.
    """
    df_ffill = df.ffill()
    out = {}

    # Build drivers from spec
    for driver, spec in driver_specs.items():
        series = build_driver(df_ffill, spec)
        if series is not None:
            out[driver] = series
    if not out:
        return pd.DataFrame(index=df_ffill.index)  # empty, but preserves index
    result = pd.DataFrame(out)
    # Drop the first row (NaN from diff/log)
    result = result.iloc[1:]
    return result

# %%
# --- 2. Driver specification dictionaries ---

# Example: driver_specs for each currency
driver_specs_map = {
    "eur_df2": {
        "EURUSD": {"type": "single", "col": "EURUSD Curncy"},
        "BBDXY": {"type": "single", "col": "BBDXY_ex_EUR"},
        "EMFX": {"type": "single", "col": "EMFXDBET Index"},
        "2y yield": {"type": "spread", "left": "GECU2YR Index", "right": "USGG2YR Index"},
        "5y yield": {"type": "spread", "left": "GECU5YR Index", "right": "USGG5YR Index"},
        "10y yield": {"type": "spread", "left": "GECU10YR Index", "right": "USGG10YR Index"},
        "3m1m forward OIS": {"type": "spread", "left": "G0013 3M1M BLC2 Curncy", "right": "S0042FS 3M1M BLC Curncy"},
        "6m1m forward OIS": {"type": "spread", "left": "G0013 6M1M BLC2 Curncy", "right": "S0042FS 6M1M BLC Curncy"},
        "1y1m forward OIS": {"type": "spread", "left": "G0013 1Y1M BLC2 Curncy", "right": "S0042FS 1Y1M BLC Curncy"},
        "Real 2y yield": {"type": "spread", "left": "RR2YHEA Index", "right": "RR2YHUS Index"},
        "Local - S&P500": {"type": "spread", "left": "SXXP Index", "right": "SPX Index"},
        "Local - Wilshire": {"type": "spread", "left": "SXXP Index", "right": "FTW5000 Index"},
        "Local - Dow Jones": {"type": "spread", "left": "SXXP Index", "right": "INDU Index"},
        "MSCI World - S&P500": {"type": "spread", "left": "MXWO Index", "right": "SPX Index"},
        "MSCI World - Wilshire": {"type": "spread", "left": "MXWO Index", "right": "FTW5000 Index"},
        "MSCI World - Dow Jones": {"type": "spread", "left": "MXWO Index", "right": "INDU Index"},
        "MSCI World ex-US": {"type": "single", "col": "MXWOU Index"},
        "MSCI EM": {"type": "single", "col": "MXEF Index"},
        "Local Index": {"type": "single", "col": "SXXP Index"},
        "BCOM Index": {"type": "single", "col": "BCOM Index"},
        "Gold": {"type": "single", "col": "XAU Curncy"},
        "Oil": {"type": "single", "col": "CO1 Comdty"},
        "UK Natural Gas": {"type": "single", "col": "FN1 Comdty"},
        "TTF Natural Gas": {"type": "single", "col": "TZT1 Comdty"},
        "NY Natural Gas": {"type": "single", "col": "NG1 COMB Comdty"},
        "Copper COMEX": {"type": "single", "col": "HGA Comdty"},
        "Copper LME": {"type": "single", "col": "LMCADS03 Comdty"},
        "VIX": {"type": "single", "col": "VIX Index"},
        "USTs Volatility": {"type": "single", "col": "MOVE Index"},
        "G10 FX Volatility": {"type": "single", "col": "JPMVG71M Index"},
    },
    "gbp_df2": {
        "GBPUSD": {"type": "single", "col": "GBPUSD Curncy"},
        "BBDXY": {"type": "single", "col": "BBDXY_ex_GBP"},
        "EMFX": {"type": "single", "col": "EMFXDBET Index"},
        "2y yield": {"type": "spread", "left": "GTGBP2YR Corp", "right": "USGG2YR Index"},
        "5y yield": {"type": "spread", "left": "GTGBP5YR Corp", "right": "USGG5YR Index"},
        "10y yield": {"type": "spread", "left": "GTGBP10YR Corp", "right": "USGG10YR Index"},
        "3m1m forward OIS": {"type": "spread", "left": "G0022 3M1M BLC2 Curncy", "right": "S0042FS 3M1M BLC Curncy"},
        "6m1m forward OIS": {"type": "spread", "left": "G0022 6M1M BLC2 Curncy", "right": "S0042FS 6M1M BLC Curncy"},
        "1y1m forward OIS": {"type": "spread", "left": "G0022 1Y1M BLC2 Curncy", "right": "S0042FS 1Y1M BLC Curncy"},
        "Real 2y yield": {"type": "spread", "left": "RR2YHGB Index", "right": "RR2YHUS Index"},
        "Local - S&P500": {"type": "spread", "left": "UKX Index", "right": "SPX Index"},
        "Local - Wilshire": {"type": "spread", "left": "UKX Index", "right": "FTW5000 Index"},
        "Local - Dow Jones": {"type": "spread", "left": "UKX Index", "right": "INDU Index"},
        "MSCI World - S&P500": {"type": "spread", "left": "MXWO Index", "right": "SPX Index"},
        "MSCI World - Wilshire": {"type": "spread", "left": "MXWO Index", "right": "FTW5000 Index"},
        "MSCI World - Dow Jones": {"type": "spread", "left": "MXWO Index", "right": "INDU Index"},
        "MSCI World ex-US": {"type": "single", "col": "MXWOU Index"},
        "MSCI EM": {"type": "single", "col": "MXEF Index"},
        "Local Index": {"type": "single", "col": "UKX Index"},
        "BCOM Index": {"type": "single", "col": "BCOM Index"},
        "Gold": {"type": "single", "col": "XAU Curncy"},
        "Oil": {"type": "single", "col": "CO1 Comdty"},
        "UK Natural Gas": {"type": "single", "col": "FN1 Comdty"},
        "TTF Natural Gas": {"type": "single", "col": "TZT1 Comdty"},
        "NY Natural Gas": {"type": "single", "col": "NG1 COMB Comdty"},
        "Copper COMEX": {"type": "single", "col": "HGA Comdty"},
        "Copper LME": {"type": "single", "col": "LMCADS03 Comdty"},
        "VIX": {"type": "single", "col": "VIX Index"},
        "USTs Volatility": {"type": "single", "col": "MOVE Index"},
        "G10 FX Volatility": {"type": "single", "col": "JPMVG71M Index"},
    },
    "jpy_df2": {
        "USDJPY": {"type": "single", "col": "USDJPY Curncy"},
        "BBDXY": {"type": "single", "col": "BBDXY_ex_JPY"},
        "Asia EMFX": {"type": "single", "col": "CTTWBUSA Index"},
        "2y yield": {"type": "spread", "left": "USGG2YR Index", "right": "GTJPY2YR Corp"},
        "5y yield": {"type": "spread", "left": "USGG5YR Index", "right": "GTJPY5YR Corp"},
        "10y yield": {"type": "spread", "left": "USGG10YR Index", "right": "GTJPY10YR Corp"},
        "Real 2y yield": {"type": "spread", "left": "RR2YHUS Index", "right": "RR2YHJP Index"},
        "Local - S&P500": {"type": "spread", "left": "NXY Index", "right": "SPX Index"},
        "Local - Wilshire": {"type": "spread", "left": "NXY Index", "right": "FTW5000 Index"},
        "Local - Dow Jones": {"type": "spread", "left": "NXY Index", "right": "INDU Index"},
        "MSCI World - S&P500": {"type": "spread", "left": "MXWO Index", "right": "SPX Index"},
        "MSCI World - Wilshire": {"type": "spread", "left": "MXWO Index", "right": "FTW5000 Index"},
        "MSCI World - Dow Jones": {"type": "spread", "left": "MXWO Index", "right": "INDU Index"},
        "MSCI World ex-US": {"type": "single", "col": "MXWOU Index"},
        "MSCI EM": {"type": "single", "col": "MXEF Index"},
        "Local Index": {"type": "single", "col": "NXY Index"},
        "BCOM Index": {"type": "single", "col": "BCOM Index"},
        "Gold": {"type": "single", "col": "XAU Curncy"},
        "Oil": {"type": "single", "col": "CO1 Comdty"},
        "UK Natural Gas": {"type": "single", "col": "FN1 Comdty"},
        "TTF Natural Gas": {"type": "single", "col": "TZT1 Comdty"},
        "NY Natural Gas": {"type": "single", "col": "NG1 COMB Comdty"},
        "Copper COMEX": {"type": "single", "col": "HGA Comdty"},
        "Copper LME": {"type": "single", "col": "LMCADS03 Comdty"},
        "VIX": {"type": "single", "col": "VIX Index"},
        "USTs Volatility": {"type": "single", "col": "MOVE Index"},
        "G10 FX Volatility": {"type": "single", "col": "JPMVG71M Index"},
    },
    "chf_df2": {
        "USDCHF": {"type": "single", "col": "USDCHF Curncy"},
        "BBDXY": {"type": "single", "col": "BBDXY_ex_CHF"},
        "EMFX": {"type": "single", "col": "EMFXDBET Index"},
        "2y yield": {"type": "spread", "left": "USGG2YR Index", "right": "GTCHF2YR Corp"},
        "5y yield": {"type": "spread", "left": "USGG5YR Index", "right": "GTCHF5YR Corp"},
        "10y yield": {"type": "spread", "left": "USGG10YR Index", "right": "GTCHF10YR Corp"},
        "Real 2y yield": {"type": "spread", "left": "RR2YHUS Index", "right": "RR2YHCH Index"},
        "Local - S&P500": {"type": "spread", "left": "SMI Index", "right": "SPX Index"},
        "Local - Wilshire": {"type": "spread", "left": "SMI Index", "right": "FTW5000 Index"},
        "Local - Dow Jones": {"type": "spread", "left": "SMI Index", "right": "INDU Index"},
        "MSCI World - S&P500": {"type": "spread", "left": "MXWO Index", "right": "SPX Index"},
        "MSCI World - Wilshire": {"type": "spread", "left": "MXWO Index", "right": "FTW5000 Index"},
        "MSCI World - Dow Jones": {"type": "spread", "left": "MXWO Index", "right": "INDU Index"},
        "MSCI World ex-US": {"type": "single", "col": "MXWOU Index"},
        "MSCI EM": {"type": "single", "col": "MXEF Index"},
        "Local Index": {"type": "single", "col": "SMI Index"},
        "BCOM Index": {"type": "single", "col": "BCOM Index"},
        "Gold": {"type": "single", "col": "XAU Curncy"},
        "Oil": {"type": "single", "col": "CO1 Comdty"},
        "UK Natural Gas": {"type": "single", "col": "FN1 Comdty"},
        "TTF Natural Gas": {"type": "single", "col": "TZT1 Comdty"},
        "NY Natural Gas": {"type": "single", "col": "NG1 COMB Comdty"},
        "Copper COMEX": {"type": "single", "col": "HGA Comdty"},
        "Copper LME": {"type": "single", "col": "LMCADS03 Comdty"},
        "VIX": {"type": "single", "col": "VIX Index"},
        "USTs Volatility": {"type": "single", "col": "MOVE Index"},
        "G10 FX Volatility": {"type": "single", "col": "JPMVG71M Index"},
    },
    "cad_df2": {
        "USDCAD": {"type": "single", "col": "USDCAD Curncy"},
        "BBDXY": {"type": "single", "col": "BBDXY_ex_CAD"},
        "EMFX": {"type": "single", "col": "EMFXDBET Index"},
        "2y yield": {"type": "spread", "left": "USGG2YR Index", "right": "GTCAD2YR Corp"},
        "5y yield": {"type": "spread", "left": "USGG5YR Index", "right": "GTCAD5YR Corp"},
        "10y yield": {"type": "spread", "left": "USGG10YR Index", "right": "GTCAD10YR Corp"},
        "3m1m forward OIS": {"type": "spread", "left": "S0042FS 3M1M BLC Curncy", "right": "G0007 3M1M BLC2 Curncy"},
        "6m1m forward OIS": {"type": "spread", "left": "S0042FS 6M1M BLC Curncy", "right": "G0007 6M1M BLC2 Curncy"},
        "1y1m forward OIS": {"type": "spread", "left": "S0042FS 1Y1M BLC Curncy", "right": "G0007 1Y1M BLC2 Curncy"},
        "Real 2y yield": {"type": "spread", "left": "RR2YHUS Index", "right": "RR2YHCA Index"},
        "Local - S&P500": {"type": "spread", "left": "SPTSX Index", "right": "SPX Index"},
        "Local - Wilshire": {"type": "spread", "left": "SPTSX Index", "right": "FTW5000 Index"},
        "Local - Dow Jones": {"type": "spread", "left": "SPTSX Index", "right": "INDU Index"},
        "MSCI World - S&P500": {"type": "spread", "left": "MXWO Index", "right": "SPX Index"},
        "MSCI World - Wilshire": {"type": "spread", "left": "MXWO Index", "right": "FTW5000 Index"},
        "MSCI World - Dow Jones": {"type": "spread", "left": "MXWO Index", "right": "INDU Index"},
        "MSCI World ex-US": {"type": "single", "col": "MXWOU Index"},
        "MSCI EM": {"type": "single", "col": "MXEF Index"},
        "Local Index": {"type": "single", "col": "SPTSX Index"},
        "BCOM Index": {"type": "single", "col": "BCOM Index"},
        "Gold": {"type": "single", "col": "XAU Curncy"},
        "Oil": {"type": "single", "col": "CO1 Comdty"},
        "UK Natural Gas": {"type": "single", "col": "FN1 Comdty"},
        "TTF Natural Gas": {"type": "single", "col": "TZT1 Comdty"},
        "NY Natural Gas": {"type": "single", "col": "NG1 COMB Comdty"},
        "Copper COMEX": {"type": "single", "col": "HGA Comdty"},
        "Copper LME": {"type": "single", "col": "LMCADS03 Comdty"},
        "VIX": {"type": "single", "col": "VIX Index"},
        "USTs Volatility": {"type": "single", "col": "MOVE Index"},
        "G10 FX Volatility": {"type": "single", "col": "JPMVG71M Index"},
        "Crude oil WCS": {"type": "single", "col": "USCRWCAS Index"},
    },
    "aud_df2": {
        "AUDUSD": {"type": "single", "col": "AUDUSD Curncy"},
        "BBDXY": {"type": "single", "col": "BBDXY_ex_AUD"},
        "Asia EMFX": {"type": "single", "col": "CTTWBUSA Index"},
        "2y yield": {"type": "spread", "left": "GTAUD2YR Corp", "right": "USGG2YR Index"},
        "5y yield": {"type": "spread", "left": "GTAUD5YR Corp", "right": "USGG5YR Index"},
        "10y yield": {"type": "spread", "left": "GTAUD10YR Corp", "right": "USGG10YR Index"},
        "Real 2y yield": {"type": "spread", "left": "RR2YHAU Index", "right": "RR2YHUS Index"},
        "Local - S&P500": {"type": "spread", "left": "AS51 Index", "right": "SPX Index"},
        "Local - Wilshire": {"type": "spread", "left": "AS51 Index", "right": "FTW5000 Index"},
        "Local - Dow Jones": {"type": "spread", "left": "AS51 Index", "right": "INDU Index"},
        "MSCI World - S&P500": {"type": "spread", "left": "MXWO Index", "right": "SPX Index"},
        "MSCI World - Wilshire": {"type": "spread", "left": "MXWO Index", "right": "FTW5000 Index"},
        "MSCI World - Dow Jones": {"type": "spread", "left": "MXWO Index", "right": "INDU Index"},
        "MSCI World ex-US": {"type": "single", "col": "MXWOU Index"},
        "MSCI EM": {"type": "single", "col": "MXEF Index"},
        "Local Index": {"type": "single", "col": "AS51 Index"},
        "BCOM Index": {"type": "single", "col": "BCOM Index"},
        "Gold": {"type": "single", "col": "XAU Curncy"},
        "Oil": {"type": "single", "col": "CO1 Comdty"},
        "UK Natural Gas": {"type": "single", "col": "FN1 Comdty"},
        "TTF Natural Gas": {"type": "single", "col": "TZT1 Comdty"},
        "NY Natural Gas": {"type": "single", "col": "NG1 COMB Comdty"},
        "Copper COMEX": {"type": "single", "col": "HGA Comdty"},
        "Copper LME": {"type": "single", "col": "LMCADS03 Comdty"},
        "VIX": {"type": "single", "col": "VIX Index"},
        "USTs Volatility": {"type": "single", "col": "MOVE Index"},
        "G10 FX Volatility": {"type": "single", "col": "JPMVG71M Index"},
        "Iron ore": {"type": "single", "col": "SCOH6 COMB Comdty"},
        "Coking coal": {"type": "single", "col": "IACA COMB Comdty"},
    },
    "nzd_df2": {
        "NZDUSD": {"type": "single", "col": "NZDUSD Curncy"},
        "BBDXY": {"type": "single", "col": "BBDXY Curncy"},
        "Asia EMFX": {"type": "single", "col": "CTTWBUSA Index"},
        "2y yield": {"type": "spread", "left": "GTNZD2YR Corp", "right": "USGG2YR Index"},
        "5y yield": {"type": "spread", "left": "GTNZD5YR Corp", "right": "USGG5YR Index"},
        "10y yield": {"type": "spread", "left": "GTNZD10YR Corp", "right": "USGG10YR Index"},
        "Real 2y yield": {"type": "spread", "left": "RR2YHnz Index", "right": "RR2YHUS Index"},
        "Local - S&P500": {"type": "spread", "left": "NZX20X Index", "right": "SPX Index"},
        "Local - Wilshire": {"type": "spread", "left": "NZX20X Index", "right": "FTW5000 Index"},
        "Local - Dow Jones": {"type": "spread", "left": "NZX20X Index", "right": "INDU Index"},
        "MSCI World - S&P500": {"type": "spread", "left": "MXWO Index", "right": "SPX Index"},
        "MSCI World - Wilshire": {"type": "spread", "left": "MXWO Index", "right": "FTW5000 Index"},
        "MSCI World - Dow Jones": {"type": "spread", "left": "MXWO Index", "right": "INDU Index"},
        "MSCI World ex-US": {"type": "single", "col": "MXWOU Index"},
        "MSCI EM": {"type": "single", "col": "MXEF Index"},
        "Local Index": {"type": "single", "col": "NZX20X Index"},
        "BCOM Index": {"type": "single", "col": "BCOM Index"},
        "Gold": {"type": "single", "col": "XAU Curncy"},
        "Oil": {"type": "single", "col": "CO1 Comdty"},
        "UK Natural Gas": {"type": "single", "col": "FN1 Comdty"},
        "TTF Natural Gas": {"type": "single", "col": "TZT1 Comdty"},
        "NY Natural Gas": {"type": "single", "col": "NG1 COMB Comdty"},
        "Copper COMEX": {"type": "single", "col": "HGA Comdty"},
        "Copper LME": {"type": "single", "col": "LMCADS03 Comdty"},
        "VIX": {"type": "single", "col": "VIX Index"},
        "USTs Volatility": {"type": "single", "col": "MOVE Index"},
        "G10 FX Volatility": {"type": "single", "col": "JPMVG71M Index"},
        "Whole milk": {"type": "single", "col": "OMRA Comdty"},
        "Skimmed milk": {"type": "single", "col": "FSPA Comdty"},
    },
    "sek_df2": {
        "USDSEK": {"type": "single", "col": "USDSEK Curncy"},
        "BBDXY": {"type": "single", "col": "BBDXY Curncy"},
        "EMFX": {"type": "single", "col": "EMFXDBET Index"},
        "2y yield": {"type": "spread", "left": "USGG2YR Index", "right": "GTSEK2YR Corp"},
        "5y yield": {"type": "spread", "left": "USGG5YR Index", "right": "GTSEK5YR Corp"},
        "10y yield": {"type": "spread", "left": "USGG10YR Index", "right": "GTSEK10YR Corp"},
        "Real 2y yield": {"type": "spread", "left": "RR2YHSE Index", "right": "RR2YHUS Index"},
        "Local - S&P500": {"type": "spread", "left": "OMX Index", "right": "SPX Index"},
        "Local - Wilshire": {"type": "spread", "left": "OMX Index", "right": "FTW5000 Index"},
        "Local - Dow Jones": {"type": "spread", "left": "OMX Index", "right": "INDU Index"},
        "MSCI World - S&P500": {"type": "spread", "left": "MXWO Index", "right": "SPX Index"},
        "MSCI World - Wilshire": {"type": "spread", "left": "MXWO Index", "right": "FTW5000 Index"},
        "MSCI World - Dow Jones": {"type": "spread", "left": "MXWO Index", "right": "INDU Index"},
        "MSCI World ex-US": {"type": "single", "col": "MXWOU Index"},
        "MSCI EM": {"type": "single", "col": "MXEF Index"},
        "Local Index": {"type": "single", "col": "OMX Index"},
        "BCOM Index": {"type": "single", "col": "BCOM Index"},
        "Gold": {"type": "single", "col": "XAU Curncy"},
        "Oil": {"type": "single", "col": "CO1 Comdty"},
        "UK Natural Gas": {"type": "single", "col": "FN1 Comdty"},
        "TTF Natural Gas": {"type": "single", "col": "TZT1 Comdty"},
        "NY Natural Gas": {"type": "single", "col": "NG1 COMB Comdty"},
        "Copper COMEX": {"type": "single", "col": "HGA Comdty"},
        "Copper LME": {"type": "single", "col": "LMCADS03 Comdty"},
        "VIX": {"type": "single", "col": "VIX Index"},
        "USTs Volatility": {"type": "single", "col": "MOVE Index"},
        "G10 FX Volatility": {"type": "single", "col": "JPMVG71M Index"},
    },
    "nok_df2": {
        "USDNOK": {"type": "single", "col": "USDNOK Curncy"},
        "BBDXY": {"type": "single", "col": "BBDXY Curncy"},
        "EMFX": {"type": "single", "col": "EMFXDBET Index"},
        "2y yield": {"type": "spread", "left": "USGG2YR Index", "right": "GTNOK2YR Corp"},
        "5y yield": {"type": "spread", "left": "USGG5YR Index", "right": "GTNOK5YR Corp"},
        "10y yield": {"type": "spread", "left": "USGG10YR Index", "right": "GTNOK10YR Corp"},
        "Real 2y yield": {"type": "spread", "left": "RR2YHNO Index", "right": "RR2YHUS Index"},
        "Local - S&P500": {"type": "spread", "left": "OBX Index", "right": "SPX Index"},
        "Local - Wilshire": {"type": "spread", "left": "OBX Index", "right": "FTW5000 Index"},
        "Local - Dow Jones": {"type": "spread", "left": "OBX Index", "right": "INDU Index"},
        "MSCI World - S&P500": {"type": "spread", "left": "MXWO Index", "right": "SPX Index"},
        "MSCI World - Wilshire": {"type": "spread", "left": "MXWO Index", "right": "FTW5000 Index"},
        "MSCI World - Dow Jones": {"type": "spread", "left": "MXWO Index", "right": "INDU Index"},
        "MSCI World ex-US": {"type": "single", "col": "MXWOU Index"},
        "MSCI EM": {"type": "single", "col": "MXEF Index"},
        "Local Index": {"type": "single", "col": "OBX Index"},
        "BCOM Index": {"type": "single", "col": "BCOM Index"},
        "Gold": {"type": "single", "col": "XAU Curncy"},
        "Oil": {"type": "single", "col": "CO1 Comdty"},
        "UK Natural Gas": {"type": "single", "col": "FN1 Comdty"},
        "TTF Natural Gas": {"type": "single", "col": "TZT1 Comdty"},
        "NY Natural Gas": {"type": "single", "col": "NG1 COMB Comdty"},
        "Copper COMEX": {"type": "single", "col": "HGA Comdty"},
        "Copper LME": {"type": "single", "col": "LMCADS03 Comdty"},
        "VIX": {"type": "single", "col": "VIX Index"},
        "USTs Volatility": {"type": "single", "col": "MOVE Index"},
        "G10 FX Volatility": {"type": "single", "col": "JPMVG71M Index"},

    },
}

# %%
# --- 3. Main processing loop ---

processed_df_map = {}

for name, df in df2_map.items():
    driver_specs = driver_specs_map.get(name, {})
    processed_df = process_dataframe(df, driver_specs)
    # Assign to processed_df_map
    processed_df_map[name.replace('_df2', '_df_processed')] = processed_df
    # Assign to global variable
    globals()[name.replace('_df2', '_df_processed')] = processed_df

# --- 4. Sanity check: print shapes of all processed DataFrames ---

for name, df in processed_df_map.items():
    print(f"{name}: {df.shape}")
# Out:
# eur_df_processed: (6776, 30)
# gbp_df_processed: (6776, 30)
# jpy_df_processed: (6776, 27)
# chf_df_processed: (6776, 27)
# cad_df_processed: (6776, 31)
# aud_df_processed: (6776, 29)
# nzd_df_processed: (6776, 29)
# nok_df_processed: (6776, 27)
# sek_df_processed: (6776, 27)

# %%
nok_df_processed.tail(3)
# Out:
#               USDNOK     BBDXY  EMFX  2y yield  5y yield  10y yield  \
# 2026-02-17  0.002584  0.000296   0.0    0.0939    0.0672     0.0635
# 2026-02-18 -0.004500  0.002085   0.0    0.0362    0.0284     0.0021
# NaT         0.000000  0.000000   0.0    0.0000    0.0000     0.0000
#
#             Real 2y yield  Local - S&P500  Local - Wilshire  \
# 2026-02-17        -0.0249       -0.005064         -0.004952
# 2026-02-18        -0.0312        0.014279          0.013433
# NaT                0.0000        0.000000          0.000000
#
#             Local - Dow Jones  ...      Gold       Oil  UK Natural Gas  \
# 2026-02-17          -0.004684  ... -0.023140 -0.018079       -0.019767
# 2026-02-18           0.015519  ...  0.024331  0.029953        0.071604
# NaT                  0.000000  ...  0.000000  0.000000        0.000000
#
#             TTF Natural Gas  NY Natural Gas  Copper COMEX  Copper LME  \
# 2026-02-17        -0.035607       -0.067606     -0.027408   -0.018139
# 2026-02-18         0.051880       -0.018985      0.024932    0.000000
# NaT                0.000000        0.000000      0.000000    0.000000
#
#                  VIX  USTs Volatility  G10 FX Volatility
# 2026-02-17 -0.043873        -0.018138          -0.001369
# 2026-02-18 -0.066742         0.000000           0.000000
# NaT         0.000000         0.000000           0.000000
#
# [3 rows x 27 columns]

# %%
nzd_df_processed.tail(4)
# Out:
#               NZDUSD     BBDXY  Asia EMFX  2y yield  5y yield  10y yield  \
# 2026-02-16 -0.000994  0.001353  -0.001826   -0.0290   -0.0290    -0.0280
# 2026-02-17  0.002649  0.000296   0.000529   -0.0449   -0.0332    -0.0275
# 2026-02-18 -0.009635  0.002085   0.000333   -0.1292   -0.1184    -0.0761
# NaT         0.000000  0.000000   0.000000    0.0000    0.0000     0.0000
#
#             Real 2y yield  Local - S&P500  Local - Wilshire  \
# 2026-02-16         0.0000       -0.005580         -0.005580
# 2026-02-17        -0.0249       -0.007377         -0.007266
# 2026-02-18        -0.0312        0.008244          0.007398
# NaT                0.0000        0.000000          0.000000
#
#             Local - Dow Jones  ...  UK Natural Gas  TTF Natural Gas  \
# 2026-02-16          -0.005580  ...       -0.049741        -0.050387
# 2026-02-17          -0.006998  ...       -0.019767        -0.035607
# 2026-02-18           0.009484  ...        0.071604         0.051880
# NaT                  0.000000  ...        0.000000         0.000000
#
#             NY Natural Gas  Copper COMEX  Copper LME       VIX  \
# 2026-02-16        0.000000      0.000000   -0.002371  0.028710
# 2026-02-17       -0.067606     -0.027408   -0.018139 -0.043873
# 2026-02-18       -0.018985      0.024932    0.000000 -0.066742
# NaT               0.000000      0.000000    0.000000  0.000000
#
#             USTs Volatility  G10 FX Volatility  Whole milk  Skimmed milk
# 2026-02-16         0.000000          -0.055866   -0.002667     -0.018538
# 2026-02-17        -0.018138          -0.001369    0.001334     -0.000832
# 2026-02-18         0.000000           0.000000    0.014560      0.000000
# NaT                0.000000           0.000000    0.000000      0.000000
#
# [4 rows x 29 columns]

# %%
# --- Rolling Z-Score Transformation for Processed DataFrames with Clipping ---
import re

# Collect all *_df_processed dataframes into a dictionary
df_processed_map = {k: v for k, v in globals().items() if re.match(r"^[a-z]{3}_df_processed$", k) and isinstance(v, pd.DataFrame)}

# Apply rolling z-score transformation, clip at +/-4, and rename keys
df_1yz_map = {}
window = 252

for key, df in df_processed_map.items():
    # 1. Calculate rolling z-score. 
    # Use min_periods=1 if you want the z-score to start calculating immediately (expanding window)
    # Or leave it as is if you strictly want a 252-day lookback (first 251 rows of each col will be NaN)
    z = (df - df.rolling(window).mean()) / df.rolling(window).std()
    
    # 2. CHANGE: Remove the global dropna(). 
    # Use how='all' to only drop rows where EVERY column is empty (e.g., weekends/holidays)
    # This preserves the starting point of your earliest available data.
    z = z.dropna(how='all')
    
    # 3. Hard clip at +/-4
    z = z.clip(lower=-4, upper=4)
    
    # 4. Rename key: e.g., eur_df_processed -> eur_df_1yz
    new_key = re.sub(r'_df_processed$', '_df_1yz', key)
    df_1yz_map[new_key] = z

# Print verification
first_key = next(iter(df_1yz_map))
print(f"{first_key} shape: {df_1yz_map[first_key].shape}")
print(f"Start date for {first_key}: {df_1yz_map[first_key].index.min()}")

# Create separate variables in globals
for key, df in df_1yz_map.items():
    globals()[key] = df
# Out:
# eur_df_1yz shape: (6525, 30)
# Start date for eur_df_1yz: 2001-02-16 00:00:00

# %%
eur_df_1yz.tail(4)
# Out:
#               EURUSD     BBDXY      EMFX  2y yield  5y yield  10y yield  \
# 2026-02-16 -0.397856  0.403918 -0.188272  0.049163 -0.011268  -0.069078
# 2026-02-17 -0.039087  0.107894 -0.197980 -0.653230 -0.621194  -0.593702
# 2026-02-18 -0.653263  0.767694 -0.192530 -0.328103 -0.435476  -0.339620
# NaT        -0.088258  0.071760 -0.188116 -0.044199 -0.045252  -0.036586
#
#             3m1m forward OIS  6m1m forward OIS  1y1m forward OIS  \
# 2026-02-16         -0.043846          0.028075          0.112850
# 2026-02-17          0.084851         -0.612191         -0.598390
# 2026-02-18         -0.159278         -0.109819         -0.234961
# NaT                -0.031236         -0.027627         -0.044685
#
#             Real 2y yield  ...      Gold       Oil  UK Natural Gas  \
# 2026-02-16      -0.063027  ... -0.784570  0.703971       -1.561056
# 2026-02-17      -0.470285  ... -1.624470 -0.925105       -0.590200
# 2026-02-18      -0.608047  ...  1.420507  1.563215        2.338681
# NaT             -0.079234  ... -0.136936  0.004611        0.038778
#
#             TTF Natural Gas  NY Natural Gas  Copper COMEX  Copper LME  \
# 2026-02-16        -1.712614        0.011515     -0.033143   -0.276930
# 2026-02-17        -1.189007       -0.999938     -1.157423   -1.474066
# 2026-02-18         1.852199       -0.265904      0.991257   -0.088564
# NaT                0.044926        0.022714     -0.033926   -0.091106
#
#                  VIX  USTs Volatility  G10 FX Volatility
# 2026-02-16  0.338728         0.030585          -1.299085
# 2026-02-17 -0.519915        -0.403626          -0.016356
# 2026-02-18 -0.783906         0.041632           0.017230
# NaT         0.010088         0.044603           0.021333
#
# [4 rows x 30 columns]

# %%
import matplotlib.pyplot as plt

def plot_driver(df_name, column_name):
    """
    Plot a time series from a specified dataframe and column in df_1yz_map.
    Args:
        df_name (str): Name of the dataframe in df_1yz_map (e.g., 'aud_df_1yz').
        column_name (str): Name of the column (driver) to plot (e.g., '2y yield').
    Returns:
        matplotlib.figure.Figure: The matplotlib figure object.
    Raises:
        KeyError: If the dataframe or column does not exist.
    """
    # Validate dataframe existence
    if df_name not in df_1yz_map:
        raise KeyError(f"DataFrame '{df_name}' not found in df_1yz_map.")
    df = df_1yz_map[df_name]
    # Validate column existence
    if column_name not in df.columns:
        raise KeyError(f"Column '{column_name}' not found in DataFrame '{df_name}'.")
    series = df[column_name]
    # Plotting
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.plot(series.index, series.values, label=column_name)
    ax.set_title(f"{column_name} — {df_name}", fontsize=16)
    ax.set_xlabel("Date", fontsize=12)
    ax.set_ylabel("Z-Score", fontsize=12)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    ax.legend()
    plt.tight_layout()
    return fig

# Example usage:
plot_driver("eur_df_1yz", "5y yield")

# %%
eur_df_1yz.columns
# Out:
# Index(['EURUSD', 'BBDXY', 'EMFX', '2y yield', '5y yield', '10y yield',
#        '3m1m forward OIS', '6m1m forward OIS', '1y1m forward OIS',
#        'Real 2y yield', 'Local - S&P500', 'Local - Wilshire',
#        'Local - Dow Jones', 'MSCI World - S&P500', 'MSCI World - Wilshire',
#        'MSCI World - Dow Jones', 'MSCI World ex-US', 'MSCI EM', 'Local Index',
#        'BCOM Index', 'Gold', 'Oil', 'UK Natural Gas', 'TTF Natural Gas',
#        'NY Natural Gas', 'Copper COMEX', 'Copper LME', 'VIX',
#        'USTs Volatility', 'G10 FX Volatility'],
#       dtype='str')

# %%
# Example usage for univariate rolling OLS fair value calculation
from src.univariate_rolling_ols import univariate_rolling_ols_fair_value, get_fair_value_comparison

# Run the rolling OLS and fair value calculation
predicted_changes_map, fair_value_map = univariate_rolling_ols_fair_value(
    processed_df_map=processed_df_map,
    df2_map=df2_map,  # or None if not available
    window=252,
    method_map=None  # or provide a dict if needed
)

# Get fair value comparison for a specific currency and driver
currency = "eur_df_processed"  # example, use your actual key
example_driver = processed_df_map[currency].columns[1]  # first driver column
comparison_df = get_fair_value_comparison(
    currency=currency,
    driver=example_driver,
    processed_df_map=processed_df_map,
    df2_map=df2_map,
    predicted_changes_map=predicted_changes_map,
    fair_value_map=fair_value_map
)

# Display the result
display(comparison_df.head())
# Out:
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\venv\Lib\site-packages\statsmodels\regression\rolling.py:255: RuntimeWarning: divide by zero encountered in scalar divide
#   s2 = ssr / (nobs - tot_params)
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\venv\Lib\site-packages\statsmodels\regression\rolling.py:272: RuntimeWarning: divide by zero encountered in log
#   llf = -np.log(ssr) * nobs2  # concentrated likelihood
# c:\Users\tilik\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\venv\Lib\site-packages\statsmodels\regression\rolling.py:255: RuntimeWarning: invalid value encountered in scalar divide
#   s2 = ssr / (nobs - tot_params)
#             Actual_Level  Fair_Value_BBDXY
# 2000-03-02     -0.007326         -0.007326
# 2000-03-03     -0.007276         -0.007326
# 2000-03-06      0.000000         -0.007326
# 2000-03-07     -0.000209         -0.007326
# 2000-03-08      0.002709         -0.007326

# %%
from src.rolling_univariate_fair_value import build_univariate_fair_value_maps


predicted_changes_map, fair_value_map = build_univariate_fair_value_maps(
processed_df_map,
original_df_map=df2_map,
window=252,
)
df_out = get_fair_value_comparison("nok_df_processed", "BBDXY", fair_value_map)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 4
#       1 from src.rolling_univariate_fair_value import build_univariate_fair_value_maps
# ----> 4 predicted_changes_map, fair_value_map = build_univariate_fair_value_maps(
#       5 processed_df_map,
#       6 original_df_map=df2_map,
#       7 window=252,
#       8 )
#       9 df_out = get_fair_value_comparison("nok_df_processed", "BBDXY", fair_value_map)
#
# File ~\Cambridge\Year_1\D200\fx_valuation\fxvaluation_d200_am3483\src\rolling_univariate_fair_value.py:155, in build_univariate_fair_value_maps(processed_df_map, original_df_map, window, method_map, base_value_map)
#     152     base_value = actual_level.reindex(df.index).loc[start_idx]
#     154 if base_value is None or pd.isna(base_value):
# --> 155     raise ValueError(
#     156         f"Base value not found for {df_name} ({driver}). "
#     157         "Provide original_df_map or base_value_map."
#     158     )
#     160 fair_level = _reconstruct_level(pred_series, base_value, method=method, start_index=start_idx)
#     162 result = pd.DataFrame(index=df.index)
#
# ValueError: Base value not found for chf_df_processed (BBDXY). Provide original_df_map or base_value_map.
