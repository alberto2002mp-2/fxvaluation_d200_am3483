# %% [markdown]
# # 4. Stage 2 Fair Value and Signal Diagnostics
#
# This notebook documents the transition from driver discovery to fair-value estimation, valuation-gap monitoring, and signal interpretation.
#
# ## Narrative Flow
# - Build the Stage 2 fair-value path
# - Inspect the standardized valuation gap
# - Relate the diagnostics to the final audit outputs

# %%
from pathlib import Path
import sys

cwd = Path.cwd()
if (cwd / "src").exists():
    project_root = cwd
elif (cwd.parent / "src").exists():
    project_root = cwd.parent
else:
    raise FileNotFoundError("Could not locate project root containing 'src'.")

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import numpy as np
import pandas as pd
from IPython.display import display
import statsmodels.api as sm

# %%
from src.stage2_fair_value_runner import run_stage2_fair_value

res_df = run_stage2_fair_value(
    "eur",
    start_date="2022-01-01",
)
res_df.tail()
# Out:
#            Model_Name  Actual_Price  Macro_Anchor_Price  Fair_Value_Price  \
# Date
# 2026-02-12        ols        1.1871            1.191531          1.191531
# 2026-02-13        ols        1.1868            1.192230          1.192230
# 2026-02-16        ols        1.1851            1.190749          1.190749
# 2026-02-17        ols        1.1855            1.186554          1.186554
# 2026-02-18        ols        1.1823            1.182822          1.182822
#
#             Actual_Ret  Pred_Ret     Error        R2    Adj_R2      RMSE  ...  \
# Date                                                                      ...
# 2026-02-12   -0.008424 -0.036211  0.027787  0.351093  0.308773  0.314104  ...
# 2026-02-13   -0.025275  0.058669 -0.083944  0.363545  0.322037  0.309644  ...
# 2026-02-16   -0.143345 -0.124313 -0.019032  0.365671  0.324302  0.309146  ...
# 2026-02-17    0.033747 -0.352880  0.386627  0.394190  0.354680  0.302642  ...
# 2026-02-18   -0.270293 -0.315022  0.044729  0.356275  0.314293  0.311653  ...
#
#             Final_Loss  Epochs_Trained  Retuned  Recenter_Event  Cum_Error  \
# Date
# 2026-02-12         NaN             NaN     True           False  -0.053707
# 2026-02-13         NaN             NaN     True           False  -0.059204
# 2026-02-16         NaN             NaN     True           False  -0.051900
# 2026-02-17         NaN             NaN     True           False   0.027832
# 2026-02-18         NaN             NaN     True           False   0.030904
#
#            Macro_Gap  Signal_Z   Error_Z   Signal Days_In_Signal
# Date
# 2026-02-12 -0.004431 -1.534378 -1.534378  NEUTRAL              0
# 2026-02-13 -0.005430 -1.648823 -1.648823  NEUTRAL              0
# 2026-02-16 -0.005649 -1.662135 -1.662135  NEUTRAL              0
# 2026-02-17 -0.001054 -1.065063 -1.065063  NEUTRAL              0
# 2026-02-18 -0.000522 -0.993297 -0.993297  NEUTRAL              0
#
# [5 rows x 46 columns]

# %%
from src.stage2_fair_value_runner import run_stage2_fair_value

df = run_stage2_fair_value(
    "eur",
    window=140,
    error_sum_window=22,
    z_window=120,
    start_date="2021-01-01",
    show_plot=True,
)

# %%
from src.stage2_fair_value_runner import run_stage2_fair_value_ensemble

ens = run_stage2_fair_value_ensemble(
    "eur",
    # keep defaults or override for sensitivity tests
    confirmation_threshold=-1.5,
    start_date="2021-01-01",
    show_plot=True,
)
ens.tail()
# Out:
#            Model_Name  Actual_Price  Macro_Anchor_Price  Fair_Value_Price  \
# Date
# 2026-02-12        ols        1.1871            1.191531          1.191531
# 2026-02-13        ols        1.1868            1.192230          1.192230
# 2026-02-16        ols        1.1851            1.190749          1.190749
# 2026-02-17        ols        1.1855            1.186554          1.186554
# 2026-02-18        ols        1.1823            1.182822          1.182822
#
#             Actual_Ret  Pred_Ret     Error        R2    Adj_R2      RMSE  ...  \
# Date                                                                      ...
# 2026-02-12   -0.008424 -0.036211  0.027787  0.351093  0.308773  0.314104  ...
# 2026-02-13   -0.025275  0.058669 -0.083944  0.363545  0.322037  0.309644  ...
# 2026-02-16   -0.143345 -0.124313 -0.019032  0.365671  0.324302  0.309146  ...
# 2026-02-17    0.033747 -0.352880  0.386627  0.394190  0.354680  0.302642  ...
# 2026-02-18   -0.270293 -0.315022  0.044729  0.356275  0.314293  0.311653  ...
#
#             Signal_Z_Fast  Error_Z_Fast  Signal_Fast  Days_In_Signal_Fast  \
# Date
# 2026-02-12      -1.697373     -1.697373      NEUTRAL                    0
# 2026-02-13      -1.749265     -1.749265      NEUTRAL                    0
# 2026-02-16      -1.704183     -1.704183      NEUTRAL                    0
# 2026-02-17      -1.112482     -1.112482      NEUTRAL                    0
# 2026-02-18      -1.014271     -1.014271      NEUTRAL                    0
#
#             Signal_Z_Slow Error_Z_Slow  Macro_Gap_Slow Signal_Slow  \
# Date
# 2026-02-12       0.448175     0.448175       -0.003334     NEUTRAL
# 2026-02-13       0.399597     0.399597       -0.004534     NEUTRAL
# 2026-02-16       0.379330     0.379330       -0.004872     NEUTRAL
# 2026-02-17       0.515565     0.515565       -0.001015     NEUTRAL
# 2026-02-18       0.541726     0.541726       -0.000262     NEUTRAL
#
#            Days_In_Signal_Slow   Signal
# Date
# 2026-02-12                   0  NEUTRAL
# 2026-02-13                   0  NEUTRAL
# 2026-02-16                   0  NEUTRAL
# 2026-02-17                   0  NEUTRAL
# 2026-02-18                   0  NEUTRAL
#
# [5 rows x 52 columns]

# %%
from src.stage2_fair_value_runner import run_stage2_fair_value

# Option 1: auto-display from inside the function
res_df = run_stage2_fair_value("eur", start_date="2002-01-01", show_plot=True)
